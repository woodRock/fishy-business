# %% [markdown]
# # 03: Oil and Cross-species Adulteration
#
# This notebook addresses food fraud detection, including species mixing and mineral oil adulteration.

# %%
import os
import sys
import numpy as np
import plotly.express as px
from sklearn.metrics import mean_absolute_error

sys.path.append(os.path.abspath(".."))
from fishy import TrainingConfig, run_unified_training

DATA_PATH = "../data/REIMS.xlsx"

# %% [markdown]
# ## 1. Cross-Species Mixing
# Detecting adulteration where high-value fish is mixed with cheaper alternatives.

# %%
cfg_cross = TrainingConfig(model="mlp", dataset="cross-species", file_path=DATA_PATH, epochs=10, wandb_log=False)
res_cross = run_unified_training(cfg_cross)
print(f"Cross-species Accuracy: {res_cross.get('val_balanced_accuracy', 0):.4f}")

# %% [markdown]
# ## 2. Oil Adulteration (Ordinal Analysis)
# Quantifying the level of Mineral Oil dilution. We treat this as an ordinal problem.

# %%
cfg_oil = TrainingConfig(model="rf", dataset="oil", file_path=DATA_PATH, wandb_log=False)
res_oil = run_unified_training(cfg_oil)

# Ordinal MAE calculation
oil_map = {0: 50, 1: 25, 2: 10, 3: 5, 4: 1, 5: 0.1, 6: 0}
preds = res_oil["predictions"]
y_true = np.array([oil_map[idx] for idx in preds["labels"]])
y_pred = np.array([oil_map[idx] for idx in preds["preds"]])
print(f"Oil Adulteration MAE: {mean_absolute_error(y_true, y_pred):.2f}%")
