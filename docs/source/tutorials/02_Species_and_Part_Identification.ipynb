# %% [markdown]
# # 02: Fish Species and Part Identification
#
# This notebook demonstrates multi-class classification for identifying both the species of fish and the specific anatomical part.

# %%
import os
import sys
import plotly.express as px
from sklearn.metrics import confusion_matrix

sys.path.append(os.path.abspath(".."))
from fishy import TrainingConfig, run_unified_training, display_final_summary

DATA_PATH = "../data/REIMS.xlsx"

# %% [markdown]
# ## 1. Species Identification (Deep Learning)
# Using a Transformer model to classify between Hoki and Mackerel.

# %%
cfg_species = TrainingConfig(model="transformer", dataset="species", file_path=DATA_PATH, epochs=10, wandb_log=False)
res_species = run_unified_training(cfg_species)
display_final_summary(res_species)

# %% [markdown]
# ## 2. Anatomical Part Identification (Classic ML)
# Using a Random Forest to identify parts like Fillet, Head, and Liver.

# %%
cfg_part = TrainingConfig(model="rf", dataset="part", file_path=DATA_PATH, wandb_log=False)
res_part = run_unified_training(cfg_part)
display_final_summary(res_part)
